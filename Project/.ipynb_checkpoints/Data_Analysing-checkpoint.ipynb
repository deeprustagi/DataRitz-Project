# %% [markdown]
# # PROJECT -- ********** Determination of Person's Health **********

# %% [markdown]
# > This section is for dataset description and its preparation.

# %% [markdown]
# ## Importing packages

# %%
#Import Package

import pandas as pd
import numpy as np
import pandas_profiling as pp

# %%
# read csv file

data = pd.read_csv(r'C:\DataRitz Project\Person-s-health\Dataset\Dataset.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Datset Understanding

# %%
# read csv file and view top 5 rows

data = pd.read_csv(r'C:\DataRitz Project\Person-s-health\Dataset\Dataset.csv')
data.head(5)
# Out:
#    Male  6.153918281925378  109.72120510564179  4
# 0  Male           5.731826           73.622879  1
# 1  Male           6.175842           96.497744  2
# 2  Male           5.977582           99.809704  3
# 3  Male           5.823483           93.598806  3
# 4  Male           5.604418           69.042355  1

# %%
# don't have attributes name then what ????

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * column names

# %%
# read csv file with columns name

col = ['Gender', 'Height', 'Weight', 'Index']
data = pd.read_csv(r'C:\DataRitz Project\Person-s-health\Dataset\Dataset.csv',names=col)

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Head

# %%
# top 5 rows by default

data.head()
# Out:
#   Gender    Height      Weight  Index
# 0   Male  6.153918  109.721205      4
# 1   Male  5.731826   73.622879      1
# 2   Male  6.175842   96.497744      2
# 3   Male  5.977582   99.809704      3
# 4   Male  5.823483   93.598806      3

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
#
# * Tail

# %%
# bottom 5 rows by default

data.tail()
# Out:
#       Gender    Height     Weight  Index
# 9995  Female  5.514388  62.041283      1
# 9996  Female  5.588930  77.504471      4
# 9997  Female  5.322333  58.275494      2
# 9998  Female  5.752854  74.322315      3
# 9999  Female  5.162021  51.550427      1

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Shape

# %%
# shape of data

data.shape
# Out:
# (10000, 4)

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * columns

# %%
# columns in data

data.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Information

# %%
# data information as concise view

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
# Gender    10000 non-null object
# Height    10000 non-null float64
# Weight    10000 non-null float64
# Index     10000 non-null int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 312.6+ KB

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Size

# %%
# size of data

data.size
# Out:
# 40000

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Datatypes

# %%
# data type of each attribute

data.dtypes
# Out:
# Gender     object
# Height    float64
# Weight    float64
# Index       int64
# dtype: object

# %%
# all datatypes are correct as per requirements

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Datatypes Count

# %%
# count the attributes of similar data type

data.dtypes.value_counts()
# Out:
# float64    2
# object     1
# int64      1
# dtype: int64

# %%
# selecting data of similar data type

data_float = data.select_dtypes(include=['float64'])
data_float.head()
# Out:
#      Height      Weight
# 0  6.153918  109.721205
# 1  5.731826   73.622879
# 2  6.175842   96.497744
# 3  5.977582   99.809704
# 4  5.823483   93.598806

# %% [markdown]
# @@@@@@@@@@@@@@@@@@@
# * Statistical values

# %%
# some statistical values over data

data.describe()
# Out:
#              Height        Weight         Index
# count  10000.000000  10000.000000  10000.000000
# mean       5.530630     73.228201      2.222200
# std        0.320627     14.564160      0.865507
# min        4.521928     29.347519      0.000000
# 25%        5.292135     61.606105      2.000000
# 50%        5.526506     73.125041      2.000000
# 75%        5.764522     84.898769      3.000000
# max        6.583229    122.465413      4.000000

# %% [markdown]
# # Data Report

# %%
# use to filter warning due to version

import warnings
warnings.filterwarnings('ignore')

# forming report in html format using Pandas_Profiling 

profile = pp.ProfileReport(data)
profile.to_file('report.html')

# %% [markdown]
# ## Checking for Missing values

# %%
# return True for all missing values

data.isnull()
# Out:
#       Gender  Height  Weight  Index
# 0      False   False   False  False
# 1      False   False   False  False
# 2      False   False   False  False
# 3      False   False   False  False
# 4      False   False   False  False
# ...      ...     ...     ...    ...
# 9995   False   False   False  False
# 9996   False   False   False  False
# 9997   False   False   False  False
# 9998   False   False   False  False
# 9999   False   False   False  False
#
# [10000 rows x 4 columns]

# %%
# returns number of missing values per every column

data.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# Index     0
# dtype: int64

# %%
# no null values so no need to fill the missing values

# %% [markdown]
# ## Checking for Duplicates

# %%
# return True for duplicates

data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# return the duplicates rows

data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
#  no duplicates so no need to drop the rows

# %% [markdown]
# > Hence, we can say that
# * As Dataset is of shape (10000, 4) i.e, 10000 rows and 4 columns.
# * Dataset contains data of 10000 people without any missing value or duplicates as checked above.
# * Data of one person include [ Gender, Height, Weight, and Index ] as attributes.
# * The attributes are in required datatype so, no need to convert.
